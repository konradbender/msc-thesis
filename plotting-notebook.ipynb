# %% [markdown]
# ## This notebook was used to produce the plots where three bitmaps for different steps in the simulation are shown.

# %%
import sys
sys.path.append('../')

import importlib
import plotting.plot_bitmaps as plot_bitmaps
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

# %%
importlib.reload(plot_bitmaps)
# 4, 7 and 3.
fig, ax = plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-19", 
                                rep=3,
                                iters=(int(0), int(10e5), int(3e6)), save=False, title=False)
fig.tight_layout()
fig.savefig("thesis_results/cover-image.pdf", bbox_inches='tight')
# Out:
# /var/folders/29/50th2yxs2kj93wnhfmd4hkrw0000gn/T/ipykernel_88160/2493755207.py:6: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-32", 
                                rep=4,
                                iters=(int(600e3), int(1e6), int(2e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,000,000'}>,
#         <Axes: title={'center': 'Iter. 2,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-24", 
                                rep=3,
                                iters=(int(600e3), int(1.1e6), int(6e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,100,000'}>,
#         <Axes: title={'center': 'Iter. 6,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-24", 
                                rep=5,
                                iters=(int(600e3), int(1e6), int(4e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,000,000'}>,
#         <Axes: title={'center': 'Iter. 4,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-24", 
                                rep=6,
                                iters=(int(600e3), int(1.5e6), int(10e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,500,000'}>,
#         <Axes: title={'center': 'Iter. 10,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-19", 
                                rep=3,
                                iters=(int(700e3), int(1e6), int(3e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 700,000'}>,
#         <Axes: title={'center': 'Iter. 1,000,000'}>,
#         <Axes: title={'center': 'Iter. 3,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-19", 
                                rep=4,
                                iters=(int(600e3), int(1e6), int(2e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,000,000'}>,
#         <Axes: title={'center': 'Iter. 2,000,000'}>], dtype=object))

# %%
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-19", 
                                rep=7,
                                iters=(int(600e3), int(1e6), int(4e6)), save=True, title=True)
# Out:
# (<Figure size 1100x350 with 3 Axes>,
#  array([<Axes: title={'center': 'Iter. 600,000'}>,
#         <Axes: title={'center': 'Iter. 1,000,000'}>,
#         <Axes: title={'center': 'Iter. 4,000,000'}>], dtype=object))
