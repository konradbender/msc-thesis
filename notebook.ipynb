# %%
import sys
sys.path.append('../')

import importlib
import plot_bitmaps
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

# %%
importlib.reload(plot_bitmaps)
plot_bitmaps.plot_bitmap("/Users/konrad/code/school/msc-thesis/results/from-remote/0816_14-09-47/rep-0/bitmap_results/", 9500000)
plt.show()

# "bwr" cmap makes red the +1
