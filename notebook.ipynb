# %%
import sys
sys.path.append('../')

import importlib
import plot_bitmaps
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

# %%
importlib.reload(plot_bitmaps)
# 4, 7 and 3.
plot_bitmaps.plot_three_bitmaps("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-19", 
                                rep=3,
                                iters=(int(7e5), int(10e5), int(3e6)))
plt.show()
# Out:
# /Users/konrad/code/school/msc-thesis/plot_bitmaps.py:73: UserWarning: The figure layout has changed to tight
#   fig.legend(handles=patches, ncols=2)

# %%
dir = "/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-24"
import os
os.path.basename(dir)
# Out:
# '0826_19-14-24'

# %%
import plot_traces
importlib.reload(plot_traces)

plot_traces.one_plot_for_all("/Users/konrad/code/school/msc-thesis/results/from-remote/0826_19-14-32")
